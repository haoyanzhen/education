# %% [markdown]
# # matplotlib简单的绘图

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## 常用

# %%
a1 = np.arange(30)*0.1
b1 = np.sin(a1)
# plt.plot(a1, b1, 'b^-.')  # cyan
plt.plot(a1, b1, color='red', linewidth=0.7)

# %%
plt.scatter(a1, b1)

# %%
a2 = np.vstack(np.meshgrid(np.linspace(0,1,100), np.linspace(0,1,100))).reshape(2,-1).T
b2 = a2[:,0]**2 + a2[:,1]**2
plt.scatter(x=a2[:,0],y=a2[:,1],c=b2, cmap='ocean')
plt.colorbar()

# %%
# 直方图
a3 = np.random.randn(10000)
plt.hist(a3,bins=20)
# Out:
# (array([   4.,    6.,   14.,   51.,  125.,  274.,  505.,  760., 1125.,
#         1324., 1427., 1407., 1069.,  806.,  523.,  329.,  157.,   62.,
#           20.,   12.]),
#  array([-3.81996279, -3.45966982, -3.09937686, -2.7390839 , -2.37879093,
#         -2.01849797, -1.65820501, -1.29791204, -0.93761908, -0.57732612,
#         -0.21703315,  0.14325981,  0.50355277,  0.86384574,  1.2241387 ,
#          1.58443166,  1.94472463,  2.30501759,  2.66531055,  3.02560352,
#          3.38589648]),
#  <BarContainer object of 20 artists>)

# %%
# 柱状图
a4 = np.linspace(-2,2,5)
b4 = np.array([2,4,10,5,3])
plt.bar(a4,b4)
# Out:
# <BarContainer object of 5 artists>

# %%
# 步进图
plt.step(a4,b4,where='mid')

# %%
# 饼图
a5 = np.array([3,2,5])
plt.pie(a5, labels=['apple', 'pear', 'peach'])
# Out:
# ([<matplotlib.patches.Wedge at 0x24c0f4459a0>,
# ...
#  [Text(0.6465637441936395, 0.8899187180267095, 'apple'),
#   Text(-0.8899187482945419, 0.6465637025335369, 'pear'),
#   Text(1.0298943251329445e-07, -1.0999999999999954, 'peach')])

# %% [markdown]
# ## 作业

# %%
t1 = np.vstack(np.meshgrid(np.arange(10),np.arange(10))).reshape(2,-1)
plt.scatter(t1[0],t1[1])

# %%
plt.plot(t1[0],t1[1],'y-->')

# %%
import pandas as pd

pd.load_txt("")

# %%
a = open("./test005.txt", "r")
a
# Out:
# <_io.TextIOWrapper name='./test005.txt' mode='r' encoding='UTF-8'>

# %%
t2 = a.read()
t2
# Out:
# '0 1\n1 2'

# %%
a.readlines()
# Out:
# []

# %%
t2 = t2.split('\n')
t2l = []
for i in t2:
    t2l.append(i.split(' '))
t2l
# Out:
# [['0', '1'], ['1', '2']]

# %%
np.array(t2l, dtype=np.int32)
# Out:
# array([[0, 1],
#        [1, 2]])

# %%
a.close()

# %%
with open() as f:
    f.read()

# %%
np.loadtxt("./test005.txt")
# Out:
# dtype('float64')
